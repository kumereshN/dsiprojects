# %% [markdown]
# # Capstone: Sentiment Analysis on AMD vs Nvidia GPU release

# %% [markdown]
# ## Contents
# - Data Extraction
# - Data Cleaning
# - EDA
# - Model creation
# - Model Evaluation

# %%
# Common imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Set the max rows and columns for Pandas
pd.options.display.max_columns = 100
pd.options.display.max_rows = 200

# %% [markdown]
# ## Data Extraction

# %%
! pip install nest-asyncio
# Out:
# Requirement already satisfied: nest-asyncio in c:\users\trogg\.conda\envs\mlbook\lib\site-packages (1.4.3)

# %%
from pcpartpicker import API
import nest_asyncio
nest_asyncio.apply()

# %%
api = API()
cpu_data = api.retrieve("cpu")
gpu_data = api.retrieve('video-card')
# all_data = api.retrieve_all()

# %%
pd.DataFrame(gpu_data)
# Out:
#                                              video-card
# 0     GPU(brand='AMD', model='100-505724', chipset='...
# 1     GPU(brand='AMD', model='100-505841', chipset='...
# 2     GPU(brand='AMD', model='100-505956', chipset='...
# 3     GPU(brand='AMD', model='100-505957', chipset='...
# 4     GPU(brand='AMD', model='100-505989', chipset='...
# ...                                                 ...
# 4419  GPU(brand='Zotac', model='ZT-P10620A-10M', chi...
# 4420  GPU(brand='Zotac', model='ZT-P10700I-10P', chi...
# 4421  GPU(brand='Zotac', model='ZT-T20700A-10P', chi...
# 4422  GPU(brand='Zotac', model='ZT-T20700E-10P', chi...
# 4423  GPU(brand='Zotac', model='ZT-T20800G-10P', chi...
#
# [4424 rows x 1 columns]

# %%
pd.DataFrame(all_data['video-card'])
# Out:
#       brand           model               chipset                    vram  \
# 0       AMD      100-505724         FirePro W7100   {'total': 8000000000}
# 1       AMD      100-505841          FirePro 2450    {'total': 500000000}
# 2       AMD      100-505956    Radeon Pro WX 8200   {'total': 8000000000}
# 3       AMD      100-505957    Radeon Pro WX 9100  {'total': 16000000000}
# 4       AMD      100-505989         FirePro W9100  {'total': 32000000000}
# ...     ...             ...                   ...                     ...
# 4419  Zotac  ZT-P10620A-10M  GeForce GTX 1060 6GB   {'total': 6000000000}
# 4420  Zotac  ZT-P10700I-10P      GeForce GTX 1070   {'total': 8000000000}
# 4421  Zotac  ZT-T20700A-10P      GeForce RTX 2070   {'total': 8000000000}
# 4422  Zotac  ZT-T20700E-10P      GeForce RTX 2070   {'total': 8000000000}
# 4423  Zotac  ZT-T20800G-10P      GeForce RTX 2080   {'total': 8000000000}
#
#                   core_clock             boost_clock           color  length  \
# 0      {'cycles': 824000000}                    None     Black / Red   279.0
# 1      {'cycles': 600000000}                    None     Black / Red   170.0
# 2     {'cycles': 1200000000}  {'cycles': 1530000000}            Blue   267.0
# 3     {'cycles': 1200000000}  {'cycles': 1500000000}            Blue   267.0
# 4      {'cycles': 930000000}                    None     Black / Red   275.0
# ...                      ...                     ...             ...     ...
# 4419  {'cycles': 1506000000}  {'cycles': 1708000000}           Black   211.0
# 4420  {'cycles': 1506000000}  {'cycles': 1683000000}  Black / Silver   303.0
# 4421  {'cycles': 1410000000}  {'cycles': 1620000000}  Black / Silver   268.0
# 4422  {'cycles': 1410000000}  {'cycles': 1620000000}           Black   211.0
# 4423  {'cycles': 1515000000}  {'cycles': 1710000000}           Black   268.0
#
#             price
# 0       US$387.98
# 1        US$98.99
# 2       US$967.17
# 3     US$1,509.00
# 4         US$0.00
# ...           ...
# 4419      US$0.00
# 4420      US$0.00
# 4421      US$0.00
# 4422      US$0.00
# 4423      US$0.00
#
# [4424 rows x 9 columns]
